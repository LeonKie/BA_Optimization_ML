# %%
import numpy as np
import torch

# %%
torch.manual_seed(0)
from torchvision import transforms
import torch.nn.functional as F 
from torch import nn
import sys

sys.path.insert(1, '/Users/leonkiesgen/Documents/Python/BA_Optimization_ML/MaschineLearning/visualisation')
import json_ImExport

data=json_ImExport.loadData("/Users/leonkiesgen/Documents/Python/Kappa_variation_vmax70.json")
mean, std = (0.5,), (0.5,)

# Create a transform and normalise data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize(mean, std)
                              ])

# %%
class FMNIST(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(103,100)
        self.fc2 = nn.Linear(100,100)
        self.fc3 = nn.Linear(100,100)

    def forward(self,x):
        
        x = F.leaky_relu(self.fc1(x),negative_slope=0.05)
        x = F.leaky_relu(self.fc2(x),negative_slope=0.05)
        x = F.leaky_relu(self.fc3(x),negative_slope=0.05)
        #x= F.log_softmax(x_dim=1)

        return x

# %%
def prepareData(data):
    
    prepareddata=[]
    for item in data:
        inpdata=[]
        #print(item)
        #print(item["v_ini"])
        inpdata.append(item["v_ini"])
        inpdata.append(item["v_max"])
        inpdata.append(item["Power"])   
        inpdata.extend(item["Kappa"])

        #print("Input: ",inpdata)
        label=item["V_op"]

        inpdata=torch.Tensor(inpdata)
        label=torch.Tensor(label)

        tupledata=(inpdata,label)
        prepareddata.append((inpdata,label))
    
    return prepareddata


traindata=prepareData(data["list"])

# %%
model=FMNIST()

# %%
from IPython.core.debugger import set_trace

from torch import optim
criterion = nn.L1Loss()
optimizer = optim.SGD(model.parameters(), lr=0.001,momentum=0.9)

num_epochs = 1000
train_tracker, test_tracker, accuracy_tracker = [], [], []


for i in range(num_epochs):
    cum_loss = 0
    
    for batch, (inp, vel) in enumerate(traindata,1):

        #set_trace()
        optimizer.zero_grad()
        output = model(inp)
        
        
        
        loss = criterion(output, vel)
        loss.backward()
        optimizer.step()
        
        cum_loss += loss.item()
        
    #print("Weights: \n", model.fc1.weight)
    train_tracker.append(cum_loss/len(traindata))
    print(f"Epoch({i+1}/{num_epochs}) | Training loss: {cum_loss/len(traindata)} | ")
    '''
    test_loss = 0
    num_correct = 0
    total = 0
    
    for batch, (inp, vel) in enumerate(traindata,1):
        
        output = model(inp)
        batch_loss = criterion(output, vel)        
        test_loss += batch_loss.item()
    

    
    test_tracker.append(test_loss/len(traindata))
    print(f"Test loss: {test_loss/len(traindata)} | ", end='')
    accuracy_tracker.append(num_correct/total)
    print(f'Accuracy : {num_correct/total}')     
    

#print(f'\nNumber correct : {num_correct}, Total : {total}')
#print(f'Accuracy of the model after 30 epochs on the 10000 test images: {num_correct * 100 / total}% ')
    '''
# Out:
# Epoch(1/1000) | Training loss: nan |
# Epoch(2/1000) | Training loss: nan |
# Epoch(3/1000) | Training loss: nan |
# Epoch(4/1000) | Training loss: nan |
# Epoch(5/1000) | Training loss: nan |
# Epoch(6/1000) | Training loss: nan |
# Epoch(7/1000) | Training loss: nan |
# Epoch(8/1000) | Training loss: nan |
# Epoch(9/1000) | Training loss: nan |
# Epoch(10/1000) | Training loss: nan |
# Epoch(11/1000) | Training loss: nan |
# Epoch(12/1000) | Training loss: nan |
# Epoch(13/1000) | Training loss: nan |
# Epoch(14/1000) | Training loss: nan |
# Epoch(15/1000) | Training loss: nan |
# Epoch(16/1000) | Training loss: nan |
# Epoch(17/1000) | Training loss: nan |
# Epoch(18/1000) | Training loss: nan |
# Epoch(19/1000) | Training loss: nan |
# Epoch(20/1000) | Training loss: nan |
# Epoch(21/1000) | Training loss: nan |
# Epoch(22/1000) | Training loss: nan |
# Epoch(23/1000) | Training loss: nan |
# Epoch(24/1000) | Training loss: nan |
# Epoch(25/1000) | Training loss: nan |
# Epoch(26/1000) | Training loss: nan |
# Epoch(27/1000) | Training loss: nan |
# Epoch(28/1000) | Training loss: nan |
# Epoch(29/1000) | Training loss: nan |
# Epoch(30/1000) | Training loss: nan |
# Epoch(31/1000) | Training loss: nan |
# Epoch(32/1000) | Training loss: nan |
# Epoch(33/1000) | Training loss: nan |
# Epoch(34/1000) | Training loss: nan |
# Epoch(35/1000) | Training loss: nan |
# Epoch(36/1000) | Training loss: nan |
# Epoch(37/1000) | Training loss: nan |
# Epoch(38/1000) | Training loss: nan |
# Epoch(39/1000) | Training loss: nan |
# Epoch(40/1000) | Training loss: nan |
# Epoch(41/1000) | Training loss: nan |
# Epoch(42/1000) | Training loss: nan |
# Epoch(43/1000) | Training loss: nan |
# Epoch(44/1000) | Training loss: nan |
# Epoch(45/1000) | Training loss: nan |
# Epoch(46/1000) | Training loss: nan |
# Epoch(47/1000) | Training loss: nan |
# Epoch(48/1000) | Training loss: nan |
# Epoch(49/1000) | Training loss: nan |
# Epoch(50/1000) | Training loss: nan |
# Epoch(51/1000) | Training loss: nan |
# Epoch(52/1000) | Training loss: nan |
# Epoch(53/1000) | Training loss: nan |
# Epoch(54/1000) | Training loss: nan |
# Epoch(55/1000) | Training loss: nan |
# Epoch(56/1000) | Training loss: nan |
# Epoch(57/1000) | Training loss: nan |
# Epoch(58/1000) | Training loss: nan |
# Epoch(59/1000) | Training loss: nan |
# Epoch(60/1000) | Training loss: nan |
# Epoch(61/1000) | Training loss: nan |
# Epoch(62/1000) | Training loss: nan |
# Epoch(63/1000) | Training loss: nan |
# Epoch(64/1000) | Training loss: nan |
# Epoch(65/1000) | Training loss: nan |
# Epoch(66/1000) | Training loss: nan |
# Epoch(67/1000) | Training loss: nan |
# Epoch(68/1000) | Training loss: nan |
# Epoch(69/1000) | Training loss: nan |
# Epoch(70/1000) | Training loss: nan |
# Epoch(71/1000) | Training loss: nan |
# Epoch(72/1000) | Training loss: nan |
# Epoch(73/1000) | Training loss: nan |
# Epoch(74/1000) | Training loss: nan |
# Epoch(75/1000) | Training loss: nan |
# Epoch(76/1000) | Training loss: nan |
# Epoch(77/1000) | Training loss: nan |
# Epoch(78/1000) | Training loss: nan |
# Epoch(79/1000) | Training loss: nan |
# Epoch(80/1000) | Training loss: nan |
# Epoch(81/1000) | Training loss: nan |
# Epoch(82/1000) | Training loss: nan |
# Epoch(83/1000) | Training loss: nan |
# Epoch(84/1000) | Training loss: nan |
# Epoch(85/1000) | Training loss: nan |
# Epoch(86/1000) | Training loss: nan |
# Epoch(87/1000) | Training loss: nan |
# Epoch(88/1000) | Training loss: nan |
# Epoch(89/1000) | Training loss: nan |
# Epoch(90/1000) | Training loss: nan |
# Epoch(91/1000) | Training loss: nan |
# Epoch(92/1000) | Training loss: nan |
# Epoch(93/1000) | Training loss: nan |
# Epoch(94/1000) | Training loss: nan |
# Epoch(95/1000) | Training loss: nan |
# Epoch(96/1000) | Training loss: nan |
# Epoch(97/1000) | Training loss: nan |
# Epoch(98/1000) | Training loss: nan |
# Epoch(99/1000) | Training loss: nan |
# Epoch(100/1000) | Training loss: nan |
# Epoch(101/1000) | Training loss: nan |
# Epoch(102/1000) | Training loss: nan |
# Epoch(103/1000) | Training loss: nan |
# Epoch(104/1000) | Training loss: nan |
# Epoch(105/1000) | Training loss: nan |
# Epoch(106/1000) | Training loss: nan |
# Epoch(107/1000) | Training loss: nan |
# Epoch(108/1000) | Training loss: nan |
# Epoch(109/1000) | Training loss: nan |
# Epoch(110/1000) | Training loss: nan |
# Epoch(111/1000) | Training loss: nan |
# Epoch(112/1000) | Training loss: nan |
# Epoch(113/1000) | Training loss: nan |
# Epoch(114/1000) | Training loss: nan |
# Epoch(115/1000) | Training loss: nan |
# Epoch(116/1000) | Training loss: nan |
# Epoch(117/1000) | Training loss: nan |
# Epoch(118/1000) | Training loss: nan |
# Epoch(119/1000) | Training loss: nan |
# Epoch(120/1000) | Training loss: nan |
# Epoch(121/1000) | Training loss: nan |
# Epoch(122/1000) | Training loss: nan |
# Epoch(123/1000) | Training loss: nan |
# Epoch(124/1000) | Training loss: nan |
# Epoch(125/1000) | Training loss: nan |
# Epoch(126/1000) | Training loss: nan |
# Epoch(127/1000) | Training loss: nan |
# Epoch(128/1000) | Training loss: nan |
# Epoch(129/1000) | Training loss: nan |
# Epoch(130/1000) | Training loss: nan |
# Epoch(131/1000) | Training loss: nan |
# Epoch(132/1000) | Training loss: nan |
# Epoch(133/1000) | Training loss: nan |
# Epoch(134/1000) | Training loss: nan |
# Epoch(135/1000) | Training loss: nan |
# Epoch(136/1000) | Training loss: nan |
# Epoch(137/1000) | Training loss: nan |
# Epoch(138/1000) | Training loss: nan |
# Epoch(139/1000) | Training loss: nan |
# Epoch(140/1000) | Training loss: nan |
# Epoch(141/1000) | Training loss: nan |
# Epoch(142/1000) | Training loss: nan |
# Epoch(143/1000) | Training loss: nan |
# Epoch(144/1000) | Training loss: nan |
# Epoch(145/1000) | Training loss: nan |
# Epoch(146/1000) | Training loss: nan |
# Epoch(147/1000) | Training loss: nan |
# Epoch(148/1000) | Training loss: nan |
# Epoch(149/1000) | Training loss: nan |
# Epoch(150/1000) | Training loss: nan |
# Epoch(151/1000) | Training loss: nan |
# Epoch(152/1000) | Training loss: nan |
# Epoch(153/1000) | Training loss: nan |
# Epoch(154/1000) | Training loss: nan |
# Epoch(155/1000) | Training loss: nan |
# Epoch(156/1000) | Training loss: nan |
# Epoch(157/1000) | Training loss: nan |
# Epoch(158/1000) | Training loss: nan |
# Epoch(159/1000) | Training loss: nan |
# Epoch(160/1000) | Training loss: nan |
# Epoch(161/1000) | Training loss: nan |
# Epoch(162/1000) | Training loss: nan |
# Epoch(163/1000) | Training loss: nan |
# Epoch(164/1000) | Training loss: nan |
# Epoch(165/1000) | Training loss: nan |
# Epoch(166/1000) | Training loss: nan |
# Epoch(167/1000) | Training loss: nan |
# Epoch(168/1000) | Training loss: nan |
# Epoch(169/1000) | Training loss: nan |
# Epoch(170/1000) | Training loss: nan |
# Epoch(171/1000) | Training loss: nan |
# Epoch(172/1000) | Training loss: nan |
# Epoch(173/1000) | Training loss: nan |
# Epoch(174/1000) | Training loss: nan |
# Epoch(175/1000) | Training loss: nan |
# Epoch(176/1000) | Training loss: nan |
# Epoch(177/1000) | Training loss: nan |
# Epoch(178/1000) | Training loss: nan |
# Epoch(179/1000) | Training loss: nan |
# Epoch(180/1000) | Training loss: nan |
# Epoch(181/1000) | Training loss: nan |
# Epoch(182/1000) | Training loss: nan |
# Epoch(183/1000) | Training loss: nan |
# Epoch(184/1000) | Training loss: nan |
# Epoch(185/1000) | Training loss: nan |
# Epoch(186/1000) | Training loss: nan |
# Epoch(187/1000) | Training loss: nan |
# Epoch(188/1000) | Training loss: nan |
# Epoch(189/1000) | Training loss: nan |
# Epoch(190/1000) | Training loss: nan |
# Epoch(191/1000) | Training loss: nan |
# Epoch(192/1000) | Training loss: nan |
# Epoch(193/1000) | Training loss: nan |
# Epoch(194/1000) | Training loss: nan |
# Epoch(195/1000) | Training loss: nan |
# Epoch(196/1000) | Training loss: nan |
# Epoch(197/1000) | Training loss: nan |
# Epoch(198/1000) | Training loss: nan |
# Epoch(199/1000) | Training loss: nan |
# Epoch(200/1000) | Training loss: nan |
# Epoch(201/1000) | Training loss: nan |
# Epoch(202/1000) | Training loss: nan |
# Epoch(203/1000) | Training loss: nan |
# Epoch(204/1000) | Training loss: nan |
# Epoch(205/1000) | Training loss: nan |
# Epoch(206/1000) | Training loss: nan |
# Epoch(207/1000) | Training loss: nan |
# Epoch(208/1000) | Training loss: nan |
# Epoch(209/1000) | Training loss: nan |
# Epoch(210/1000) | Training loss: nan |
# Epoch(211/1000) | Training loss: nan |
# Epoch(212/1000) | Training loss: nan |
# Epoch(213/1000) | Training loss: nan |
# Epoch(214/1000) | Training loss: nan |
# Epoch(215/1000) | Training loss: nan |
# Epoch(216/1000) | Training loss: nan |
# Epoch(217/1000) | Training loss: nan |
# Epoch(218/1000) | Training loss: nan |
# Epoch(219/1000) | Training loss: nan |
# Epoch(220/1000) | Training loss: nan |
# Epoch(221/1000) | Training loss: nan |
# Epoch(222/1000) | Training loss: nan |
# Epoch(223/1000) | Training loss: nan |
# Epoch(224/1000) | Training loss: nan |
# Epoch(225/1000) | Training loss: nan |
# Epoch(226/1000) | Training loss: nan |
# Epoch(227/1000) | Training loss: nan |
# Epoch(228/1000) | Training loss: nan |
# Epoch(229/1000) | Training loss: nan |
# Epoch(230/1000) | Training loss: nan |
# Epoch(231/1000) | Training loss: nan |
# Epoch(232/1000) | Training loss: nan |
# Epoch(233/1000) | Training loss: nan |
# Epoch(234/1000) | Training loss: nan |
# Epoch(235/1000) | Training loss: nan |
# Epoch(236/1000) | Training loss: nan |
# Epoch(237/1000) | Training loss: nan |
# Epoch(238/1000) | Training loss: nan |
# Epoch(239/1000) | Training loss: nan |
# Epoch(240/1000) | Training loss: nan |
# Epoch(241/1000) | Training loss: nan |
# Epoch(242/1000) | Training loss: nan |
# Epoch(243/1000) | Training loss: nan |
# Epoch(244/1000) | Training loss: nan |
# Epoch(245/1000) | Training loss: nan |
# Epoch(246/1000) | Training loss: nan |
# Epoch(247/1000) | Training loss: nan |
# Epoch(248/1000) | Training loss: nan |
# Epoch(249/1000) | Training loss: nan |
# Epoch(250/1000) | Training loss: nan |
# Epoch(251/1000) | Training loss: nan |
# Epoch(252/1000) | Training loss: nan |
# Epoch(253/1000) | Training loss: nan |
# Epoch(254/1000) | Training loss: nan |
# Epoch(255/1000) | Training loss: nan |
# Epoch(256/1000) | Training loss: nan |
# Epoch(257/1000) | Training loss: nan |
# Epoch(258/1000) | Training loss: nan |
# Epoch(259/1000) | Training loss: nan |
# Epoch(260/1000) | Training loss: nan |
# Epoch(261/1000) | Training loss: nan |
# Epoch(262/1000) | Training loss: nan |
# Epoch(263/1000) | Training loss: nan |
# Epoch(264/1000) | Training loss: nan |
# Epoch(265/1000) | Training loss: nan |
# Epoch(266/1000) | Training loss: nan |
# Epoch(267/1000) | Training loss: nan |
# Epoch(268/1000) | Training loss: nan |
# Epoch(269/1000) | Training loss: nan |
# Epoch(270/1000) | Training loss: nan |
# Epoch(271/1000) | Training loss: nan |
# Epoch(272/1000) | Training loss: nan |
# Epoch(273/1000) | Training loss: nan |
# Epoch(274/1000) | Training loss: nan |
# Epoch(275/1000) | Training loss: nan |
# Epoch(276/1000) | Training loss: nan |
# Epoch(277/1000) | Training loss: nan |
# Epoch(278/1000) | Training loss: nan |
# Epoch(279/1000) | Training loss: nan |
# Epoch(280/1000) | Training loss: nan |
# Epoch(281/1000) | Training loss: nan |
# Epoch(282/1000) | Training loss: nan |
# Epoch(283/1000) | Training loss: nan |
# Epoch(284/1000) | Training loss: nan |
# Epoch(285/1000) | Training loss: nan |
# Epoch(286/1000) | Training loss: nan |
# Epoch(287/1000) | Training loss: nan |
# Epoch(288/1000) | Training loss: nan |
# Epoch(289/1000) | Training loss: nan |
# Epoch(290/1000) | Training loss: nan |
# Epoch(291/1000) | Training loss: nan |
# Epoch(292/1000) | Training loss: nan |
# Epoch(293/1000) | Training loss: nan |
# Epoch(294/1000) | Training loss: nan |
# Epoch(295/1000) | Training loss: nan |
# Epoch(296/1000) | Training loss: nan |
# Epoch(297/1000) | Training loss: nan |
# Epoch(298/1000) | Training loss: nan |
# Epoch(299/1000) | Training loss: nan |
# Epoch(300/1000) | Training loss: nan |
# Epoch(301/1000) | Training loss: nan |
# Epoch(302/1000) | Training loss: nan |
# Epoch(303/1000) | Training loss: nan |
# Epoch(304/1000) | Training loss: nan |
# Epoch(305/1000) | Training loss: nan |
# Epoch(306/1000) | Training loss: nan |
# Epoch(307/1000) | Training loss: nan |
# Epoch(308/1000) | Training loss: nan |
# Epoch(309/1000) | Training loss: nan |
# Epoch(310/1000) | Training loss: nan |
# Epoch(311/1000) | Training loss: nan |
# Epoch(312/1000) | Training loss: nan |
# Epoch(313/1000) | Training loss: nan |
# Epoch(314/1000) | Training loss: nan |
# Epoch(315/1000) | Training loss: nan |
# Epoch(316/1000) | Training loss: nan |
# Epoch(317/1000) | Training loss: nan |
# Epoch(318/1000) | Training loss: nan |
# Epoch(319/1000) | Training loss: nan |
# Epoch(320/1000) | Training loss: nan |
# Epoch(321/1000) | Training loss: nan |
# Epoch(322/1000) | Training loss: nan |
# Epoch(323/1000) | Training loss: nan |
# Epoch(324/1000) | Training loss: nan |
# Epoch(325/1000) | Training loss: nan |
# Epoch(326/1000) | Training loss: nan |
# Epoch(327/1000) | Training loss: nan |
# Epoch(328/1000) | Training loss: nan |
# Epoch(329/1000) | Training loss: nan |
# Epoch(330/1000) | Training loss: nan |
# Epoch(331/1000) | Training loss: nan |
# Epoch(332/1000) | Training loss: nan |
# Epoch(333/1000) | Training loss: nan |
# Epoch(334/1000) | Training loss: nan |
# Epoch(335/1000) | Training loss: nan |
# Epoch(336/1000) | Training loss: nan |
# Epoch(337/1000) | Training loss: nan |
# Epoch(338/1000) | Training loss: nan |
# Epoch(339/1000) | Training loss: nan |
# Epoch(340/1000) | Training loss: nan |
# Epoch(341/1000) | Training loss: nan |
# Epoch(342/1000) | Training loss: nan |
# Epoch(343/1000) | Training loss: nan |
# Epoch(344/1000) | Training loss: nan |
# Epoch(345/1000) | Training loss: nan |
# Epoch(346/1000) | Training loss: nan |
# Epoch(347/1000) | Training loss: nan |
# Epoch(348/1000) | Training loss: nan |
# Epoch(349/1000) | Training loss: nan |
# Epoch(350/1000) | Training loss: nan |
# Epoch(351/1000) | Training loss: nan |
# Epoch(352/1000) | Training loss: nan |
# Epoch(353/1000) | Training loss: nan |
# Epoch(354/1000) | Training loss: nan |
# Epoch(355/1000) | Training loss: nan |
# Epoch(356/1000) | Training loss: nan |
# Epoch(357/1000) | Training loss: nan |
# Epoch(358/1000) | Training loss: nan |
# Epoch(359/1000) | Training loss: nan |
# Epoch(360/1000) | Training loss: nan |
# Epoch(361/1000) | Training loss: nan |
# Epoch(362/1000) | Training loss: nan |
# Epoch(363/1000) | Training loss: nan |
# Epoch(364/1000) | Training loss: nan |
# Epoch(365/1000) | Training loss: nan |
# Epoch(366/1000) | Training loss: nan |
# Epoch(367/1000) | Training loss: nan |
# Epoch(368/1000) | Training loss: nan |
# Epoch(369/1000) | Training loss: nan |
# Epoch(370/1000) | Training loss: nan |
# Epoch(371/1000) | Training loss: nan |
# Epoch(372/1000) | Training loss: nan |
# Epoch(373/1000) | Training loss: nan |
# Epoch(374/1000) | Training loss: nan |
# Epoch(375/1000) | Training loss: nan |
# Epoch(376/1000) | Training loss: nan |
# Epoch(377/1000) | Training loss: nan |
# Epoch(378/1000) | Training loss: nan |
# Epoch(379/1000) | Training loss: nan |
# Epoch(380/1000) | Training loss: nan |
# Epoch(381/1000) | Training loss: nan |
# Epoch(382/1000) | Training loss: nan |
# Epoch(383/1000) | Training loss: nan |
# Epoch(384/1000) | Training loss: nan |
# Epoch(385/1000) | Training loss: nan |
# Epoch(386/1000) | Training loss: nan |
# Epoch(387/1000) | Training loss: nan |
# Epoch(388/1000) | Training loss: nan |
# Epoch(389/1000) | Training loss: nan |
# Epoch(390/1000) | Training loss: nan |
# Epoch(391/1000) | Training loss: nan |
# Epoch(392/1000) | Training loss: nan |
# Epoch(393/1000) | Training loss: nan |
# Epoch(394/1000) | Training loss: nan |
# Epoch(395/1000) | Training loss: nan |
# Epoch(396/1000) | Training loss: nan |
# Epoch(397/1000) | Training loss: nan |
# Epoch(398/1000) | Training loss: nan |
# Epoch(399/1000) | Training loss: nan |
# Epoch(400/1000) | Training loss: nan |
# Epoch(401/1000) | Training loss: nan |
# Epoch(402/1000) | Training loss: nan |
# Epoch(403/1000) | Training loss: nan |
# Epoch(404/1000) | Training loss: nan |
# Epoch(405/1000) | Training loss: nan |
# Epoch(406/1000) | Training loss: nan |
# Epoch(407/1000) | Training loss: nan |
# Epoch(408/1000) | Training loss: nan |
# Epoch(409/1000) | Training loss: nan |
# Epoch(410/1000) | Training loss: nan |
# Epoch(411/1000) | Training loss: nan |
# Epoch(412/1000) | Training loss: nan |
# Epoch(413/1000) | Training loss: nan |
# Epoch(414/1000) | Training loss: nan |
# Epoch(415/1000) | Training loss: nan |
# Epoch(416/1000) | Training loss: nan |
# Epoch(417/1000) | Training loss: nan |
# Epoch(418/1000) | Training loss: nan |
# Epoch(419/1000) | Training loss: nan |
# Epoch(420/1000) | Training loss: nan |
# Epoch(421/1000) | Training loss: nan |
# Epoch(422/1000) | Training loss: nan |
# Epoch(423/1000) | Training loss: nan |
# Epoch(424/1000) | Training loss: nan |
# Epoch(425/1000) | Training loss: nan |
# Epoch(426/1000) | Training loss: nan |
# Epoch(427/1000) | Training loss: nan |
# Epoch(428/1000) | Training loss: nan |
# Epoch(429/1000) | Training loss: nan |
# Epoch(430/1000) | Training loss: nan |
# Epoch(431/1000) | Training loss: nan |
# Epoch(432/1000) | Training loss: nan |
# Epoch(433/1000) | Training loss: nan |
# Epoch(434/1000) | Training loss: nan |
# Epoch(435/1000) | Training loss: nan |
# Epoch(436/1000) | Training loss: nan |
# Epoch(437/1000) | Training loss: nan |
# Epoch(438/1000) | Training loss: nan |
# Epoch(439/1000) | Training loss: nan |
# Epoch(440/1000) | Training loss: nan |
# Epoch(441/1000) | Training loss: nan |
# Epoch(442/1000) | Training loss: nan |
# Epoch(443/1000) | Training loss: nan |
# Epoch(444/1000) | Training loss: nan |
# Epoch(445/1000) | Training loss: nan |
# Epoch(446/1000) | Training loss: nan |
# Epoch(447/1000) | Training loss: nan |
# Epoch(448/1000) | Training loss: nan |
# Epoch(449/1000) | Training loss: nan |
# Epoch(450/1000) | Training loss: nan |
# Epoch(451/1000) | Training loss: nan |
# Epoch(452/1000) | Training loss: nan |
# Epoch(453/1000) | Training loss: nan |
# Epoch(454/1000) | Training loss: nan |
# Epoch(455/1000) | Training loss: nan |
# Epoch(456/1000) | Training loss: nan |
# Epoch(457/1000) | Training loss: nan |
# Epoch(458/1000) | Training loss: nan |
# Epoch(459/1000) | Training loss: nan |
# Epoch(460/1000) | Training loss: nan |
# Epoch(461/1000) | Training loss: nan |
# Epoch(462/1000) | Training loss: nan |
# Epoch(463/1000) | Training loss: nan |
# Epoch(464/1000) | Training loss: nan |
# Epoch(465/1000) | Training loss: nan |
# Epoch(466/1000) | Training loss: nan |
# Epoch(467/1000) | Training loss: nan |
# Epoch(468/1000) | Training loss: nan |
# Epoch(469/1000) | Training loss: nan |
# Epoch(470/1000) | Training loss: nan |
# Epoch(471/1000) | Training loss: nan |
# Epoch(472/1000) | Training loss: nan |
# Epoch(473/1000) | Training loss: nan |
# Epoch(474/1000) | Training loss: nan |
# Epoch(475/1000) | Training loss: nan |
# Epoch(476/1000) | Training loss: nan |
# Epoch(477/1000) | Training loss: nan |
# Epoch(478/1000) | Training loss: nan |
# Epoch(479/1000) | Training loss: nan |
# Epoch(480/1000) | Training loss: nan |
# Epoch(481/1000) | Training loss: nan |
# Epoch(482/1000) | Training loss: nan |
# Epoch(483/1000) | Training loss: nan |
# Epoch(484/1000) | Training loss: nan |
# Epoch(485/1000) | Training loss: nan |
# Epoch(486/1000) | Training loss: nan |
# Epoch(487/1000) | Training loss: nan |
# Epoch(488/1000) | Training loss: nan |
# Epoch(489/1000) | Training loss: nan |
# Epoch(490/1000) | Training loss: nan |
# Epoch(491/1000) | Training loss: nan |
# Epoch(492/1000) | Training loss: nan |
# Epoch(493/1000) | Training loss: nan |
# Epoch(494/1000) | Training loss: nan |
# Epoch(495/1000) | Training loss: nan |
# Epoch(496/1000) | Training loss: nan |
# Epoch(497/1000) | Training loss: nan |
# Epoch(498/1000) | Training loss: nan |
# Epoch(499/1000) | Training loss: nan |
# Epoch(500/1000) | Training loss: nan |
# Epoch(501/1000) | Training loss: nan |
# Epoch(502/1000) | Training loss: nan |
# Epoch(503/1000) | Training loss: nan |
# Epoch(504/1000) | Training loss: nan |
# Epoch(505/1000) | Training loss: nan |
# Epoch(506/1000) | Training loss: nan |
# Epoch(507/1000) | Training loss: nan |
# Epoch(508/1000) | Training loss: nan |
# Epoch(509/1000) | Training loss: nan |
# Epoch(510/1000) | Training loss: nan |
# Epoch(511/1000) | Training loss: nan |
# Epoch(512/1000) | Training loss: nan |
# Epoch(513/1000) | Training loss: nan |
# Epoch(514/1000) | Training loss: nan |
# Epoch(515/1000) | Training loss: nan |
# Epoch(516/1000) | Training loss: nan |
# Epoch(517/1000) | Training loss: nan |
# Epoch(518/1000) | Training loss: nan |
# Epoch(519/1000) | Training loss: nan |
# Epoch(520/1000) | Training loss: nan |
# Epoch(521/1000) | Training loss: nan |
# Epoch(522/1000) | Training loss: nan |
# Epoch(523/1000) | Training loss: nan |
# Epoch(524/1000) | Training loss: nan |
# Epoch(525/1000) | Training loss: nan |
# Epoch(526/1000) | Training loss: nan |
# Epoch(527/1000) | Training loss: nan |
# Epoch(528/1000) | Training loss: nan |
# Epoch(529/1000) | Training loss: nan |
# Epoch(530/1000) | Training loss: nan |
# Epoch(531/1000) | Training loss: nan |
# Epoch(532/1000) | Training loss: nan |
# Epoch(533/1000) | Training loss: nan |
# Epoch(534/1000) | Training loss: nan |
# Epoch(535/1000) | Training loss: nan |
# Epoch(536/1000) | Training loss: nan |
# Epoch(537/1000) | Training loss: nan |
# Epoch(538/1000) | Training loss: nan |
# Epoch(539/1000) | Training loss: nan |
# Epoch(540/1000) | Training loss: nan |
# Epoch(541/1000) | Training loss: nan |
# Epoch(542/1000) | Training loss: nan |
# Epoch(543/1000) | Training loss: nan |
# Epoch(544/1000) | Training loss: nan |
# Epoch(545/1000) | Training loss: nan |
# Epoch(546/1000) | Training loss: nan |
# Epoch(547/1000) | Training loss: nan |
# Epoch(548/1000) | Training loss: nan |
# Epoch(549/1000) | Training loss: nan |
# Epoch(550/1000) | Training loss: nan |
# Epoch(551/1000) | Training loss: nan |
# Epoch(552/1000) | Training loss: nan |
# Epoch(553/1000) | Training loss: nan |
# Epoch(554/1000) | Training loss: nan |
# Epoch(555/1000) | Training loss: nan |
# Epoch(556/1000) | Training loss: nan |
# Epoch(557/1000) | Training loss: nan |
# Epoch(558/1000) | Training loss: nan |
# Epoch(559/1000) | Training loss: nan |
# Epoch(560/1000) | Training loss: nan |
# Epoch(561/1000) | Training loss: nan |
# Epoch(562/1000) | Training loss: nan |
# Epoch(563/1000) | Training loss: nan |
# Epoch(564/1000) | Training loss: nan |
# Epoch(565/1000) | Training loss: nan |
# Epoch(566/1000) | Training loss: nan |
# Epoch(567/1000) | Training loss: nan |
# Epoch(568/1000) | Training loss: nan |
# Epoch(569/1000) | Training loss: nan |
# Epoch(570/1000) | Training loss: nan |
# Epoch(571/1000) | Training loss: nan |
# Epoch(572/1000) | Training loss: nan |
# Epoch(573/1000) | Training loss: nan |
# Epoch(574/1000) | Training loss: nan |
# Epoch(575/1000) | Training loss: nan |
# Epoch(576/1000) | Training loss: nan |
# Epoch(577/1000) | Training loss: nan |
# Epoch(578/1000) | Training loss: nan |
# Epoch(579/1000) | Training loss: nan |
# Epoch(580/1000) | Training loss: nan |
# Epoch(581/1000) | Training loss: nan |
# Epoch(582/1000) | Training loss: nan |
# Epoch(583/1000) | Training loss: nan |
# Epoch(584/1000) | Training loss: nan |
# Epoch(585/1000) | Training loss: nan |
# Epoch(586/1000) | Training loss: nan |
# Epoch(587/1000) | Training loss: nan |
# Epoch(588/1000) | Training loss: nan |
# Epoch(589/1000) | Training loss: nan |
# Epoch(590/1000) | Training loss: nan |
# Epoch(591/1000) | Training loss: nan |
# Epoch(592/1000) | Training loss: nan |
# Epoch(593/1000) | Training loss: nan |
# Epoch(594/1000) | Training loss: nan |
# Epoch(595/1000) | Training loss: nan |
# Epoch(596/1000) | Training loss: nan |
# Epoch(597/1000) | Training loss: nan |
# Epoch(598/1000) | Training loss: nan |
# Epoch(599/1000) | Training loss: nan |
# Epoch(600/1000) | Training loss: nan |
# Epoch(601/1000) | Training loss: nan |
# Epoch(602/1000) | Training loss: nan |
# Epoch(603/1000) | Training loss: nan |
# Epoch(604/1000) | Training loss: nan |
# Epoch(605/1000) | Training loss: nan |
# Epoch(606/1000) | Training loss: nan |
# Epoch(607/1000) | Training loss: nan |
# Epoch(608/1000) | Training loss: nan |
# Epoch(609/1000) | Training loss: nan |
# Epoch(610/1000) | Training loss: nan |
# Epoch(611/1000) | Training loss: nan |
# Epoch(612/1000) | Training loss: nan |
# Epoch(613/1000) | Training loss: nan |
# Epoch(614/1000) | Training loss: nan |
# Epoch(615/1000) | Training loss: nan |
# Epoch(616/1000) | Training loss: nan |
# Epoch(617/1000) | Training loss: nan |
# Epoch(618/1000) | Training loss: nan |
# Epoch(619/1000) | Training loss: nan |
# Epoch(620/1000) | Training loss: nan |
# Epoch(621/1000) | Training loss: nan |
# Epoch(622/1000) | Training loss: nan |
# Epoch(623/1000) | Training loss: nan |
# Epoch(624/1000) | Training loss: nan |
# Epoch(625/1000) | Training loss: nan |
# Epoch(626/1000) | Training loss: nan |
# Epoch(627/1000) | Training loss: nan |
# Epoch(628/1000) | Training loss: nan |
# Epoch(629/1000) | Training loss: nan |
# Epoch(630/1000) | Training loss: nan |
# Epoch(631/1000) | Training loss: nan |
# Epoch(632/1000) | Training loss: nan |
# Epoch(633/1000) | Training loss: nan |
# Epoch(634/1000) | Training loss: nan |
# Epoch(635/1000) | Training loss: nan |
# Epoch(636/1000) | Training loss: nan |
# Epoch(637/1000) | Training loss: nan |
# Epoch(638/1000) | Training loss: nan |
# Epoch(639/1000) | Training loss: nan |
# Epoch(640/1000) | Training loss: nan |
# Epoch(641/1000) | Training loss: nan |
# Epoch(642/1000) | Training loss: nan |
# Epoch(643/1000) | Training loss: nan |
# Epoch(644/1000) | Training loss: nan |
# Epoch(645/1000) | Training loss: nan |
# Epoch(646/1000) | Training loss: nan |
# Epoch(647/1000) | Training loss: nan |
# Epoch(648/1000) | Training loss: nan |
# Epoch(649/1000) | Training loss: nan |
# Epoch(650/1000) | Training loss: nan |
# Epoch(651/1000) | Training loss: nan |
# Epoch(652/1000) | Training loss: nan |
# Epoch(653/1000) | Training loss: nan |
# Epoch(654/1000) | Training loss: nan |
# Epoch(655/1000) | Training loss: nan |
# Epoch(656/1000) | Training loss: nan |
# Epoch(657/1000) | Training loss: nan |
# Epoch(658/1000) | Training loss: nan |
# Epoch(659/1000) | Training loss: nan |
# Epoch(660/1000) | Training loss: nan |
# Epoch(661/1000) | Training loss: nan |
# Epoch(662/1000) | Training loss: nan |
# Epoch(663/1000) | Training loss: nan |
# Epoch(664/1000) | Training loss: nan |
# Epoch(665/1000) | Training loss: nan |
# Epoch(666/1000) | Training loss: nan |
# Epoch(667/1000) | Training loss: nan |
# Epoch(668/1000) | Training loss: nan |
# Epoch(669/1000) | Training loss: nan |
# Epoch(670/1000) | Training loss: nan |
# Epoch(671/1000) | Training loss: nan |
# Epoch(672/1000) | Training loss: nan |
# Epoch(673/1000) | Training loss: nan |
# Epoch(674/1000) | Training loss: nan |
# Epoch(675/1000) | Training loss: nan |
# Epoch(676/1000) | Training loss: nan |
# Epoch(677/1000) | Training loss: nan |
# Epoch(678/1000) | Training loss: nan |
# Epoch(679/1000) | Training loss: nan |
# Epoch(680/1000) | Training loss: nan |
# Epoch(681/1000) | Training loss: nan |
# Epoch(682/1000) | Training loss: nan |
# Epoch(683/1000) | Training loss: nan |
# Epoch(684/1000) | Training loss: nan |
# Epoch(685/1000) | Training loss: nan |
# Epoch(686/1000) | Training loss: nan |
# Epoch(687/1000) | Training loss: nan |
# Epoch(688/1000) | Training loss: nan |
# Epoch(689/1000) | Training loss: nan |
# Epoch(690/1000) | Training loss: nan |
# Epoch(691/1000) | Training loss: nan |
# Epoch(692/1000) | Training loss: nan |
# Epoch(693/1000) | Training loss: nan |
# Epoch(694/1000) | Training loss: nan |
# Epoch(695/1000) | Training loss: nan |
# Epoch(696/1000) | Training loss: nan |
# Epoch(697/1000) | Training loss: nan |
# Epoch(698/1000) | Training loss: nan |
# Epoch(699/1000) | Training loss: nan |
# Epoch(700/1000) | Training loss: nan |
# Epoch(701/1000) | Training loss: nan |
# Epoch(702/1000) | Training loss: nan |
# Epoch(703/1000) | Training loss: nan |
# Epoch(704/1000) | Training loss: nan |
# Epoch(705/1000) | Training loss: nan |
# Epoch(706/1000) | Training loss: nan |
# Epoch(707/1000) | Training loss: nan |
# Epoch(708/1000) | Training loss: nan |
# Epoch(709/1000) | Training loss: nan |
# Epoch(710/1000) | Training loss: nan |
# Epoch(711/1000) | Training loss: nan |
# Epoch(712/1000) | Training loss: nan |
# Epoch(713/1000) | Training loss: nan |
# Epoch(714/1000) | Training loss: nan |
# Epoch(715/1000) | Training loss: nan |
# Epoch(716/1000) | Training loss: nan |
# Epoch(717/1000) | Training loss: nan |
# Epoch(718/1000) | Training loss: nan |
# Epoch(719/1000) | Training loss: nan |
# Epoch(720/1000) | Training loss: nan |
# Epoch(721/1000) | Training loss: nan |
# Epoch(722/1000) | Training loss: nan |
# Epoch(723/1000) | Training loss: nan |
# Epoch(724/1000) | Training loss: nan |
# Epoch(725/1000) | Training loss: nan |
# Epoch(726/1000) | Training loss: nan |
# Epoch(727/1000) | Training loss: nan |
# Epoch(728/1000) | Training loss: nan |
# Epoch(729/1000) | Training loss: nan |
# Epoch(730/1000) | Training loss: nan |
# Epoch(731/1000) | Training loss: nan |
# Epoch(732/1000) | Training loss: nan |
# Epoch(733/1000) | Training loss: nan |
# Epoch(734/1000) | Training loss: nan |
# Epoch(735/1000) | Training loss: nan |
# Epoch(736/1000) | Training loss: nan |
# Epoch(737/1000) | Training loss: nan |
# Epoch(738/1000) | Training loss: nan |
# Epoch(739/1000) | Training loss: nan |
# Epoch(740/1000) | Training loss: nan |
# Epoch(741/1000) | Training loss: nan |
# Epoch(742/1000) | Training loss: nan |
# Epoch(743/1000) | Training loss: nan |
# Epoch(744/1000) | Training loss: nan |
# Epoch(745/1000) | Training loss: nan |
# Epoch(746/1000) | Training loss: nan |
# Epoch(747/1000) | Training loss: nan |
# Epoch(748/1000) | Training loss: nan |
# Epoch(749/1000) | Training loss: nan |
# Epoch(750/1000) | Training loss: nan |
# Epoch(751/1000) | Training loss: nan |
# Epoch(752/1000) | Training loss: nan |
# Epoch(753/1000) | Training loss: nan |
# Epoch(754/1000) | Training loss: nan |
# Epoch(755/1000) | Training loss: nan |
# Epoch(756/1000) | Training loss: nan |
# Epoch(757/1000) | Training loss: nan |
# Epoch(758/1000) | Training loss: nan |
# Epoch(759/1000) | Training loss: nan |
# Epoch(760/1000) | Training loss: nan |
# Epoch(761/1000) | Training loss: nan |
# Epoch(762/1000) | Training loss: nan |
# Epoch(763/1000) | Training loss: nan |
# Epoch(764/1000) | Training loss: nan |
# Epoch(765/1000) | Training loss: nan |
# Epoch(766/1000) | Training loss: nan |
# Epoch(767/1000) | Training loss: nan |
# Epoch(768/1000) | Training loss: nan |
# Epoch(769/1000) | Training loss: nan |
# Epoch(770/1000) | Training loss: nan |
# Epoch(771/1000) | Training loss: nan |
# Epoch(772/1000) | Training loss: nan |
# Epoch(773/1000) | Training loss: nan |
# Epoch(774/1000) | Training loss: nan |
# Epoch(775/1000) | Training loss: nan |
# Epoch(776/1000) | Training loss: nan |
# Epoch(777/1000) | Training loss: nan |
# Epoch(778/1000) | Training loss: nan |
# Epoch(779/1000) | Training loss: nan |
# Epoch(780/1000) | Training loss: nan |
# Epoch(781/1000) | Training loss: nan |
# Epoch(782/1000) | Training loss: nan |
# Epoch(783/1000) | Training loss: nan |
# Epoch(784/1000) | Training loss: nan |
# Epoch(785/1000) | Training loss: nan |
# Epoch(786/1000) | Training loss: nan |
# Epoch(787/1000) | Training loss: nan |
# Epoch(788/1000) | Training loss: nan |
# Epoch(789/1000) | Training loss: nan |
# Epoch(790/1000) | Training loss: nan |
# Epoch(791/1000) | Training loss: nan |
# Epoch(792/1000) | Training loss: nan |
# Epoch(793/1000) | Training loss: nan |
# Epoch(794/1000) | Training loss: nan |
# Epoch(795/1000) | Training loss: nan |
# Epoch(796/1000) | Training loss: nan |
# Epoch(797/1000) | Training loss: nan |
# Epoch(798/1000) | Training loss: nan |
# Epoch(799/1000) | Training loss: nan |
# Epoch(800/1000) | Training loss: nan |
# Epoch(801/1000) | Training loss: nan |
# Epoch(802/1000) | Training loss: nan |
# Epoch(803/1000) | Training loss: nan |
# Epoch(804/1000) | Training loss: nan |
# Epoch(805/1000) | Training loss: nan |
# Epoch(806/1000) | Training loss: nan |
# Epoch(807/1000) | Training loss: nan |
# Epoch(808/1000) | Training loss: nan |
# Epoch(809/1000) | Training loss: nan |
# Epoch(810/1000) | Training loss: nan |
# Epoch(811/1000) | Training loss: nan |
# Epoch(812/1000) | Training loss: nan |
# Epoch(813/1000) | Training loss: nan |
# Epoch(814/1000) | Training loss: nan |
# Epoch(815/1000) | Training loss: nan |
# Epoch(816/1000) | Training loss: nan |
# Epoch(817/1000) | Training loss: nan |
# Epoch(818/1000) | Training loss: nan |
# Epoch(819/1000) | Training loss: nan |
# Epoch(820/1000) | Training loss: nan |
# Epoch(821/1000) | Training loss: nan |
# Epoch(822/1000) | Training loss: nan |
# Epoch(823/1000) | Training loss: nan |
# Epoch(824/1000) | Training loss: nan |
# Epoch(825/1000) | Training loss: nan |
# Epoch(826/1000) | Training loss: nan |
# Epoch(827/1000) | Training loss: nan |
# Epoch(828/1000) | Training loss: nan |
# Epoch(829/1000) | Training loss: nan |
# Epoch(830/1000) | Training loss: nan |
# Epoch(831/1000) | Training loss: nan |
# Epoch(832/1000) | Training loss: nan |
# Epoch(833/1000) | Training loss: nan |
# Epoch(834/1000) | Training loss: nan |
# Epoch(835/1000) | Training loss: nan |
# Epoch(836/1000) | Training loss: nan |
# Epoch(837/1000) | Training loss: nan |
# Epoch(838/1000) | Training loss: nan |
# Epoch(839/1000) | Training loss: nan |
# Epoch(840/1000) | Training loss: nan |
# Epoch(841/1000) | Training loss: nan |
# Epoch(842/1000) | Training loss: nan |
# Epoch(843/1000) | Training loss: nan |
# Epoch(844/1000) | Training loss: nan |
# Epoch(845/1000) | Training loss: nan |
# Epoch(846/1000) | Training loss: nan |
# Epoch(847/1000) | Training loss: nan |
# Epoch(848/1000) | Training loss: nan |
# Epoch(849/1000) | Training loss: nan |
# Epoch(850/1000) | Training loss: nan |
# Epoch(851/1000) | Training loss: nan |
# Epoch(852/1000) | Training loss: nan |
# Epoch(853/1000) | Training loss: nan |
# Epoch(854/1000) | Training loss: nan |
# Epoch(855/1000) | Training loss: nan |
# Epoch(856/1000) | Training loss: nan |
# Epoch(857/1000) | Training loss: nan |
# Epoch(858/1000) | Training loss: nan |
# Epoch(859/1000) | Training loss: nan |
# Epoch(860/1000) | Training loss: nan |
# Epoch(861/1000) | Training loss: nan |
# Epoch(862/1000) | Training loss: nan |
# Epoch(863/1000) | Training loss: nan |
# Epoch(864/1000) | Training loss: nan |
# Epoch(865/1000) | Training loss: nan |
# Epoch(866/1000) | Training loss: nan |
# Epoch(867/1000) | Training loss: nan |
# Epoch(868/1000) | Training loss: nan |
# Epoch(869/1000) | Training loss: nan |
# Epoch(870/1000) | Training loss: nan |
# Epoch(871/1000) | Training loss: nan |
# Epoch(872/1000) | Training loss: nan |
# Epoch(873/1000) | Training loss: nan |
# Epoch(874/1000) | Training loss: nan |
# Epoch(875/1000) | Training loss: nan |
# Epoch(876/1000) | Training loss: nan |
# Epoch(877/1000) | Training loss: nan |
# Epoch(878/1000) | Training loss: nan |
# Epoch(879/1000) | Training loss: nan |
# Epoch(880/1000) | Training loss: nan |
# Epoch(881/1000) | Training loss: nan |
# Epoch(882/1000) | Training loss: nan |
# Epoch(883/1000) | Training loss: nan |
# Epoch(884/1000) | Training loss: nan |
# Epoch(885/1000) | Training loss: nan |
# Epoch(886/1000) | Training loss: nan |
# Epoch(887/1000) | Training loss: nan |
# Epoch(888/1000) | Training loss: nan |
# Epoch(889/1000) | Training loss: nan |
# Epoch(890/1000) | Training loss: nan |
# Epoch(891/1000) | Training loss: nan |
# Epoch(892/1000) | Training loss: nan |
# Epoch(893/1000) | Training loss: nan |
# Epoch(894/1000) | Training loss: nan |
# Epoch(895/1000) | Training loss: nan |
# Epoch(896/1000) | Training loss: nan |
# Epoch(897/1000) | Training loss: nan |
# Epoch(898/1000) | Training loss: nan |
# Epoch(899/1000) | Training loss: nan |
# Epoch(900/1000) | Training loss: nan |
# Epoch(901/1000) | Training loss: nan |
# Epoch(902/1000) | Training loss: nan |
# Epoch(903/1000) | Training loss: nan |
# Epoch(904/1000) | Training loss: nan |
# Epoch(905/1000) | Training loss: nan |
# Epoch(906/1000) | Training loss: nan |
# Epoch(907/1000) | Training loss: nan |
# Epoch(908/1000) | Training loss: nan |
# Epoch(909/1000) | Training loss: nan |
# Epoch(910/1000) | Training loss: nan |
# Epoch(911/1000) | Training loss: nan |
# Epoch(912/1000) | Training loss: nan |
# Epoch(913/1000) | Training loss: nan |
# Epoch(914/1000) | Training loss: nan |
# Epoch(915/1000) | Training loss: nan |
# Epoch(916/1000) | Training loss: nan |
# Epoch(917/1000) | Training loss: nan |
# Epoch(918/1000) | Training loss: nan |
# Epoch(919/1000) | Training loss: nan |
# Epoch(920/1000) | Training loss: nan |
# Epoch(921/1000) | Training loss: nan |
# Epoch(922/1000) | Training loss: nan |
# Epoch(923/1000) | Training loss: nan |
# Epoch(924/1000) | Training loss: nan |
# Epoch(925/1000) | Training loss: nan |
# Epoch(926/1000) | Training loss: nan |
# Epoch(927/1000) | Training loss: nan |
# Epoch(928/1000) | Training loss: nan |
# Epoch(929/1000) | Training loss: nan |
# Epoch(930/1000) | Training loss: nan |
# Epoch(931/1000) | Training loss: nan |
# Epoch(932/1000) | Training loss: nan |
# Epoch(933/1000) | Training loss: nan |
# Epoch(934/1000) | Training loss: nan |
# Epoch(935/1000) | Training loss: nan |
# Epoch(936/1000) | Training loss: nan |
# Epoch(937/1000) | Training loss: nan |
# Epoch(938/1000) | Training loss: nan |
# Epoch(939/1000) | Training loss: nan |
# Epoch(940/1000) | Training loss: nan |
# Epoch(941/1000) | Training loss: nan |
# Epoch(942/1000) | Training loss: nan |
# Epoch(943/1000) | Training loss: nan |
# Epoch(944/1000) | Training loss: nan |
# Epoch(945/1000) | Training loss: nan |
# Epoch(946/1000) | Training loss: nan |
# Epoch(947/1000) | Training loss: nan |
# Epoch(948/1000) | Training loss: nan |
# Epoch(949/1000) | Training loss: nan |
# Epoch(950/1000) | Training loss: nan |
# Epoch(951/1000) | Training loss: nan |
# Epoch(952/1000) | Training loss: nan |
# Epoch(953/1000) | Training loss: nan |
# Epoch(954/1000) | Training loss: nan |
# Epoch(955/1000) | Training loss: nan |
# Epoch(956/1000) | Training loss: nan |
# Epoch(957/1000) | Training loss: nan |
# Epoch(958/1000) | Training loss: nan |
# Epoch(959/1000) | Training loss: nan |
# Epoch(960/1000) | Training loss: nan |
# Epoch(961/1000) | Training loss: nan |
# Epoch(962/1000) | Training loss: nan |
# Epoch(963/1000) | Training loss: nan |
# Epoch(964/1000) | Training loss: nan |
# Epoch(965/1000) | Training loss: nan |
# Epoch(966/1000) | Training loss: nan |
# Epoch(967/1000) | Training loss: nan |
# Epoch(968/1000) | Training loss: nan |
# Epoch(969/1000) | Training loss: nan |
# Epoch(970/1000) | Training loss: nan |
# Epoch(971/1000) | Training loss: nan |
# Epoch(972/1000) | Training loss: nan |
# Epoch(973/1000) | Training loss: nan |
# Epoch(974/1000) | Training loss: nan |
# Epoch(975/1000) | Training loss: nan |
# Epoch(976/1000) | Training loss: nan |
# Epoch(977/1000) | Training loss: nan |
# Epoch(978/1000) | Training loss: nan |
# Epoch(979/1000) | Training loss: nan |
# Epoch(980/1000) | Training loss: nan |
# Epoch(981/1000) | Training loss: nan |
# Epoch(982/1000) | Training loss: nan |
# Epoch(983/1000) | Training loss: nan |
# Epoch(984/1000) | Training loss: nan |
# Epoch(985/1000) | Training loss: nan |
# Epoch(986/1000) | Training loss: nan |
# Epoch(987/1000) | Training loss: nan |
# Epoch(988/1000) | Training loss: nan |
# Epoch(989/1000) | Training loss: nan |
# Epoch(990/1000) | Training loss: nan |
# Epoch(991/1000) | Training loss: nan |
# Epoch(992/1000) | Training loss: nan |
# Epoch(993/1000) | Training loss: nan |
# Epoch(994/1000) | Training loss: nan |
# Epoch(995/1000) | Training loss: nan |
# Epoch(996/1000) | Training loss: nan |
# Epoch(997/1000) | Training loss: nan |
# Epoch(998/1000) | Training loss: nan |
# Epoch(999/1000) | Training loss: nan |
# Epoch(1000/1000) | Training loss: nan |

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(train_tracker, label='Training loss')
#plt.plot(test_tracker, label='Test loss')
plt.legend()

# %%
def predict(testexample):
    
    pData=prepareData(testexample)
   # print("pData", pData)
    pData=pData[0]
    pred=model(pData[0])

    #print("Pred:", pred.tolist(), "real: ", d[1])
    # %matplotlib inline
    plt.plot(pred.tolist(),label="Pred")
    plt.plot(pData[1].tolist(),label= "Real_Optimizer")

# %%
predict([data["list"][9]])

# %%
pData=prepareData([data["list"][10]])
pData=pData[0]
pred=model(pData[0])
pred
# Out:
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan], grad_fn=<LeakyReluBackward0>)

# %%
model.fc1.weight
# Out:
# Parameter containing:
# tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], requires_grad=True)

# %%
model
# Out:
# FMNIST(
#   (fc1): Linear(in_features=103, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (fc3): Linear(in_features=100, out_features=100, bias=True)
# )
