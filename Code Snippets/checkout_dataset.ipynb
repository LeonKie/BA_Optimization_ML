# %%
import numpy as np
import matplotlib.pyplot as plt
import evaluate_track

import importlib
importlib.reload(evaluate_track)
# Out:
# .992227321686655, 2.00239002261159)
# Track (346, 2)
# This is the ZIP Track:
# ...
# range(0, 70, 5)
# Track Number:  8
# equallity befor:  (1.521536733292178, 1.9942636531579243)
# equallity after:  (1.991432531739575, 2.000009000110911)
# Track (348, 2)
# This is the ZIP Track:
# ...
# range(0, 70, 5)
# Track Number:  9
# equallity befor:  (1.521536733292178, 2.0249475107106596)
# equallity after:  (1.9973741566948144, 2.005623592403052)
# Track (347, 2)
# This is the ZIP Track:
# ...
# range(0, 70, 5)
# Track Number:  10
# equallity befor:  (1.521536733292178, 1.9963827084601322)
# equallity after:  (1.9919808259217986, 2.0003333925877578)
# Track (348, 2)
# This is the ZIP Track:
# ...
# range(0, 70, 5)
# Track Number:  11
# equallity befor:  (1.521536733292178, 1.9976261925197945)
# equallity after:  (1.9931086741953639, 2.000719141770672)
# Track (346, 2)
# This is the ZIP Track:
# ...
# range(0, 70, 5)
# Track Number:  12
# equallity befor:  (1.521536733292178, 1.9913223097910846)
# ...

# %%
data=evaluate_track.dataset

# %%
print(len(data))
plt.plot(data[304][1])
# Out:
# 5432

# %%
import pickle
with open('track_.pkl', 'wb') as f:
        pickle.dump(track_dataset, f)
