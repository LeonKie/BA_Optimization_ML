# %%
import numpy as np
import matplotlib.pyplot as plt
import evaluate_track

import importlib
#importlib.reload(evaluate_track)
# Out:
# Error: Error: Invalid response: 500 Internal Server Error

# %%
data=evaluate_track.dataset
# Out:
# Error: Error: Invalid response: 500 Internal Server Error

# %%
print(len(data))
plt.plot(data[317][1])
# Out:
# 3683

# %%
import pickle
with open('Zalazone_track.pkl', 'wb') as f:
        pickle.dump(data, f)
